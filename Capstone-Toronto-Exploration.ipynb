# %% [markdown]
# # Explore and cluster the neighborhoods in Toronto
#
# # Note:  For Toronto Exploration (3rd section of assignment), scroll down to  "Use Foursquare to get data on Toronto"

# %% [markdown]
# ## Step One:
# Scrape wikipedia page for the table of Neighborhoods
# source page: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import lxml
import requests
from IPython.display import display
#pd.options.display.max_columns = None
pd.set_option('display.max_columns', 15)
print('Modules Ready')
# Out:
# Modules Ready

# %%
wiki = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(wiki, 'lxml')
print(soup.title.text)
print(type(soup))
# Out:
# List of postal codes of Canada: M - Wikipedia
# <class 'bs4.BeautifulSoup'>

# %%
# Have a quick view of our HTML page

# print(soup.prettify())
# removing this - clutters final notebook with tons of HTML

# %% [markdown]
# ## Step Two:
# Find the pertinent data from the webpage, and put into a dataframe

# %%
# Use soup find the table body
table_body = soup.find('tbody')
#print(table_body)

# %%
# found help for this at https://datascience.stackexchange.com/questions/10857/how-to-scrape-a-table-from-a-webpage

# %%
# Create empty dataframe to store the data 
rows = table_body.find_all('tr')
df_cols = ['Postcode', 'Borough', 'Neighbourhood']
pc = pd.DataFrame(columns = df_cols)
print('starting with', len(rows), 'rows \n')


# iterate through rows, appending into dataframe
for row in rows:
    cols = row.find_all('td')
    cols = [x.text.strip() for x in cols]
    try:
        # Need a test to catch where no value exists (such as case with first line )
        if cols[0]:
            pc = pc.append({'Postcode':cols[0],
                    'Borough':cols[1],
                    'Neighbourhood':cols[2]}, ignore_index=True)
    except:
        print('hit an empty row, moving on \n')

print('output is a dataframe of this shape: ', pc.shape)
print('before cleaning, dataframe looks like\n\n', pc.head(10))
# Out:
# starting with 289 rows
#
# hit an empty row, moving on
#
# output is a dataframe of this shape:  (288, 3)
# before cleaning, dataframe looks like
#
#    Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %% [markdown]
# ## Step Three:
# Clean up the dataframe

# %%
# First remove rows where Borough is 'Not assigned'
cleanpc = pc[pc.Borough != 'Not assigned']
cleanpc.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %% [markdown]
# Compare M7A Queen's Park in the above dataframe, and the below

# %%
# Next, If a cell has a borough but a Not assigned neighborhood, set neighborhood to same as the borough
cleanpc['Neighbourhood'] = np.where(cleanpc['Neighbourhood'] == 'Not assigned', cleanpc['Borough'], cleanpc['Neighbourhood'])

cleanpc.head(10)
# Out:
# /anaconda3/anaconda2/envs/py3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Queen's Park
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %%
# Now combine Neighbourhood field when PostCode is the same
grouppc = cleanpc.groupby(['Postcode','Borough'])['Neighbourhood'].apply(','.join).reset_index()

# %% [markdown]
# ## Step Four:
# Show the final shape of the dataframe.  Also see the first few rows:

# %%
grouppc.head(10)
# Out:
#   Postcode      Borough                                  Neighbourhood
# 0      M1B  Scarborough                                  Rouge,Malvern
# 1      M1C  Scarborough           Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough                Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                         Woburn
# 4      M1H  Scarborough                                      Cedarbrae
# 5      M1J  Scarborough                            Scarborough Village
# 6      M1K  Scarborough      East Birchmount Park,Ionview,Kennedy Park
# 7      M1L  Scarborough                  Clairlea,Golden Mile,Oakridge
# 8      M1M  Scarborough  Cliffcrest,Cliffside,Scarborough Village West
# 9      M1N  Scarborough                     Birch Cliff,Cliffside West

# %%
grouppc.shape
# Out:
# (103, 3)

# %% [markdown]
# ## GeoCode:
# Find lat/lon for each of the Boroughs

# %%
grouppc[grouppc.Postcode == 'M5G']
# Out:
#    Postcode           Borough       Neighbourhood
# 57      M5G  Downtown Toronto  Central Bay Street

# %%
filepath = 'https://cocl.us/Geospatial_data'
postcodes = pd.read_csv(filepath, index_col=0)
postcodes.head()
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476

# %%
# merge lat/lon df into grouppc df
neighborhoods = pd.merge(grouppc, postcodes, left_on='Postcode', right_on='Postal Code', how='inner')
print(neighborhoods.shape)
neighborhoods.head()
# Out:
# (103, 5)
#   Postcode      Borough                         Neighbourhood   Latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# # Clustering the Data
# Explore and cluster the neighborhoods in Toronto:
#
# ## Start by mapping using folium

# %%
address = 'Downtown Toronto, ON'
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
print(location.latitude)
# Out:
# The geograpical coordinate of New York City are 43.655115, -79.380219.
# 43.655115

# %%
import folium # map rendering library
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Limit to Downtown Toronto
toronto = neighborhoods[neighborhoods['Borough'] == 'Downtown Toronto']
toronto.reset_index(drop=True, inplace = True)
toronto
# Out:
#    Postcode           Borough  \
# 0       M4W  Downtown Toronto
# 1       M4X  Downtown Toronto
# 2       M4Y  Downtown Toronto
# 3       M5A  Downtown Toronto
# 4       M5B  Downtown Toronto
# 5       M5C  Downtown Toronto
# 6       M5E  Downtown Toronto
# 7       M5G  Downtown Toronto
# 8       M5H  Downtown Toronto
# 9       M5J  Downtown Toronto
# 10      M5K  Downtown Toronto
# 11      M5L  Downtown Toronto
# 12      M5S  Downtown Toronto
# 13      M5T  Downtown Toronto
# 14      M5V  Downtown Toronto
# 15      M5W  Downtown Toronto
# 16      M5X  Downtown Toronto
# 17      M6G  Downtown Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                            Rosedale  43.679563 -79.377529
# 1                          Cabbagetown,St. James Town  43.667967 -79.367675
# 2                                Church and Wellesley  43.665860 -79.383160
# 3                            Harbourfront,Regent Park  43.654260 -79.360636
# 4                             Ryerson,Garden District  43.657162 -79.378937
# 5                                      St. James Town  43.651494 -79.375418
# 6                                         Berczy Park  43.644771 -79.373306
# 7                                  Central Bay Street  43.657952 -79.387383
# 8                              Adelaide,King,Richmond  43.650571 -79.384568
# 9     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 10            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 11                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 12                      Harbord,University of Toronto  43.662696 -79.400049
# 13            Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 14  CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 15                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 16              First Canadian Place,Underground city  43.648429 -79.382280
# 17                                           Christie  43.669542 -79.422564

# %% [markdown]
# # Use Foursquare to get data on Toronto
#
# ## To start:  focus on one particular Neighborhood: St. James Town

# %%
# I will focus on one particular neighbourhood:  St. James Town in M5E
sjt = toronto[toronto['Postcode'] == 'M5E']
sjt
# Out:
#   Postcode           Borough Neighbourhood   Latitude  Longitude
# 6      M5E  Downtown Toronto   Berczy Park  43.644771 -79.373306

# %%
lat = sjt.iloc[0,3]
lon = sjt.iloc[0,4]
print('lat and long of St. James Town is',lat,lon)
# Out:
# lat and long of St. James Town is 43.644770799999996 -79.3733064

# %%
#Explore neighborhoods using foursquare
CLIENT_ID = 'NN45UJFVE5IZ4R53ASPZXNPW1CMDQKU2SJGTOSC2IHJXXMO3' # your Foursquare ID
CLIENT_SECRET = 'IUG1IQ4OXOHZGGEGZHYRE4TTUM4MAPSTDLMNICP5MMGJNW0B' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 200
radius = 500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lon, VERSION, radius, LIMIT)
print(url)
# Out:
# https://api.foursquare.com/v2/venues/search?client_id=NN45UJFVE5IZ4R53ASPZXNPW1CMDQKU2SJGTOSC2IHJXXMO3&client_secret=IUG1IQ4OXOHZGGEGZHYRE4TTUM4MAPSTDLMNICP5MMGJNW0B&ll=43.644770799999996,-79.3733064&v=20180605&radius=500&limit=200

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cc77c46f594df21bb75435c'},
#  'response': {'venues': [{'id': '4ad94f83f964a520b91921e3',
#     'name': 'Union Station',
#     'location': {'address': '65 Front St W',
#      'crossStreet': 'btwn Bay & York St',
#      'lat': 43.645167120407564,
#      'lng': -79.38064098358154,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645167120407564,
#        'lng': -79.38064098358154}],
#      'distance': 592,
#      'postalCode': 'M5J 1E6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['65 Front St W (btwn Bay & York St)',
#       'Toronto ON M5J 1E6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'shortName': 'Train Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b62f9fcf964a520ca5b2ae3',
#     'name': 'LCBO Head Office',
#     'location': {'address': '55 Lakeshore Blvd E',
#      'crossStreet': 'at Freeland St',
#      'lat': 43.64498672511948,
#      'lng': -79.37257373421001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64498672511948,
#        'lng': -79.37257373421001}],
#      'distance': 63,
#      'postalCode': 'M5E 1A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['55 Lakeshore Blvd E (at Freeland St)',
#       'Toronto ON M5E 1A4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4f6d3663e4b068929f55a1ae',
#     'name': 'Loblaws parking',
#     'location': {'lat': 43.64454007751767,
#      'lng': -79.37416693389117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64454007751767,
#        'lng': -79.37416693389117}],
#      'distance': 73,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c0e2412c700c9b60157a3dd',
#     'name': 'LCBO Warehouse',
#     'location': {'lat': 43.64508074309677,
#      'lng': -79.37194535820687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64508074309677,
#        'lng': -79.37194535820687}],
#      'distance': 114,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4aeb719af964a52020c221e3',
#     'name': 'LCBO',
#     'location': {'address': '2 Cooper St',
#      'crossStreet': 'at Queens Quay E',
#      'lat': 43.64294379917171,
#      'lng': -79.37243989044406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64294379917171,
#        'lng': -79.37243989044406}],
#      'distance': 215,
#      'postalCode': 'M5E 1A4',
#      'cc': 'CA',
#      'neighborhood': 'Downtown Toronto',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2 Cooper St (at Queens Quay E)',
#       'Toronto ON M5E 1A4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d186941735',
#       'name': 'Liquor Store',
#       'pluralName': 'Liquor Stores',
#       'shortName': 'Liquor Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4cdc6115fc9737045703d505',
#     'name': 'London On The Esplanade Library',
#     'location': {'address': '321 38 The Esplanade',
#      'crossStreet': 'in London On The Esplanade',
#      'lat': 43.64572714543407,
#      'lng': -79.37041112014914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64572714543407,
#        'lng': -79.37041112014914}],
#      'distance': 256,
#      'postalCode': 'M5E 1A5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['321 38 The Esplanade (in London On The Esplanade)',
#       'Toronto ON M5E 1A5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '51b489fe498e77ba0dfe16c7',
#     'name': 'St Lawrence Sunday  Antique Market',
#     'location': {'lat': 43.64430120587735,
#      'lng': -79.37489828254998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64430120587735,
#        'lng': -79.37489828254998}],
#      'distance': 138,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c52dd08384c76b0aee0002b',
#     'name': 'Zip-Car',
#     'location': {'address': '25 The Esplanade',
#      'lat': 43.64481004010492,
#      'lng': -79.37597604899844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64481004010492,
#        'lng': -79.37597604899844}],
#      'distance': 215,
#      'postalCode': 'M5E 1W2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade', 'Toronto ON M5E 1W2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ef941735',
#       'name': 'Rental Car Location',
#       'pluralName': 'Rental Car Locations',
#       'shortName': 'Rental Car',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '50552d68e4b0d070fcbf588f',
#     'name': '25 The Esplanade',
#     'location': {'address': '25 The Esplanade',
#      'lat': 43.6446209603408,
#      'lng': -79.37526187780972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6446209603408,
#        'lng': -79.37526187780972}],
#      'distance': 158,
#      'postalCode': 'M5E 1W5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade', 'Toronto ON M5E 1W5', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '517daf30f2e7a9f9daabda30',
#     'name': 'Toronto Star Newspaper',
#     'location': {'address': '1 Yonge Street',
#      'crossStreet': "Queen's Quay",
#      'lat': 43.641991688840655,
#      'lng': -79.37471866607666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641991688840655,
#        'lng': -79.37471866607666}],
#      'distance': 329,
#      'postalCode': 'M5E 1E6',
#      'cc': 'CA',
#      'neighborhood': 'Harbourfront',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["1 Yonge Street (Queen's Quay)",
#       'Toronto ON M5E 1E6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '55bbaea6498ed9ea3a71b809',
#     'name': 'Go Bus Georgetown',
#     'location': {'lat': 43.64462309101012,
#      'lng': -79.37556363984855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64462309101012,
#        'lng': -79.37556363984855}],
#      'distance': 182,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '566f4edb498e7642ed574646',
#     'name': 'Well One Medical Centre',
#     'location': {'address': '18 Yonge St',
#      'lat': 43.64424663496144,
#      'lng': -79.37607017009026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64424663496144,
#        'lng': -79.37607017009026}],
#      'distance': 230,
#      'postalCode': 'M5E 1Z8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Yonge St', 'Toronto ON M5E 1Z8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4ad4c05bf964a520a0f520e3',
#     'name': 'Hotel Novotel Toronto Centre',
#     'location': {'address': '45 The Esplanade',
#      'lat': 43.64653,
#      'lng': -79.37425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64653,
#        'lng': -79.37425}],
#      'distance': 210,
#      'postalCode': 'M5E 1W2',
#      'cc': 'CA',
#      'neighborhood': 'St. Lawrence',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['45 The Esplanade', 'Toronto ON M5E 1W2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b9ee186f964a520210837e3',
#     'name': 'Subway',
#     'location': {'address': '16 Yonge St',
#      'crossStreet': 'Harbour St',
#      'lat': 43.643581131465915,
#      'lng': -79.37571939537777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643581131465915,
#        'lng': -79.37571939537777}],
#      'distance': 235,
#      'postalCode': 'M5E 2A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['16 Yonge St (Harbour St)',
#       'Toronto ON M5E 2A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bbe53a1848da593e522ea6d',
#     'name': 'St. Lawrence Market (North Building)',
#     'location': {'address': '92 Front St. E',
#      'crossStreet': 'at Jarvis St.',
#      'lat': 43.64879290161719,
#      'lng': -79.37194535820687,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64879290161719,
#        'lng': -79.37194535820687}],
#      'distance': 460,
#      'postalCode': 'M5E 1C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['92 Front St. E (at Jarvis St.)',
#       'Toronto ON M5E 1C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '50b62ff8e4b03554b930b156',
#     'name': 'RL Solutions',
#     'location': {'address': '1 Yonge St Suite 2300',
#      'crossStreet': 'Queens Quay',
#      'lat': 43.64335261447072,
#      'lng': -79.37499176278953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64335261447072,
#        'lng': -79.37499176278953}],
#      'distance': 208,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Yonge St Suite 2300 (Queens Quay)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '56e58f58cd1044008ca46165',
#     'name': 'Beaver Tail',
#     'location': {'lat': 43.645309323392325,
#      'lng': -79.37170890023334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645309323392325,
#        'lng': -79.37170890023334}],
#      'distance': 141,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4e5fc67bb61c67886dc913f7',
#     'name': 'LCBO Parkette',
#     'location': {'address': 'Cooper St & Queens Quay E',
#      'lat': 43.643517699525624,
#      'lng': -79.37147794070006,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643517699525624,
#        'lng': -79.37147794070006}],
#      'distance': 202,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Cooper St & Queens Quay E',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bc386482a89ef3b4c26f588',
#     'name': 'Keyboards',
#     'location': {'lat': 43.64497,
#      'lng': -79.376096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64497,
#        'lng': -79.376096}],
#      'distance': 225,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b4f5765f964a520190227e3',
#     'name': 'London on the Espanade',
#     'location': {'address': '38 The Esplanade',
#      'crossStreet': '1 Scott St',
#      'lat': 43.64696058734161,
#      'lng': -79.37455901006861,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64696058734161,
#        'lng': -79.37455901006861}],
#      'distance': 263,
#      'postalCode': 'M5e1a5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['38 The Esplanade (1 Scott St)',
#       'Toronto ON M5e1a5',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4e30448cb61c88c3a7a0b776',
#     'name': 'Eidei Productions Corporation',
#     'location': {'lat': 43.64333497891312,
#      'lng': -79.37255024795165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64333497891312,
#        'lng': -79.37255024795165}],
#      'distance': 171,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4fb24141e4b0aed64c676ca8',
#     'name': 'In balance By NOVOTEL',
#     'location': {'lat': 43.64673279571995,
#      'lng': -79.3745573538183,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64673279571995,
#        'lng': -79.3745573538183}],
#      'distance': 240,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5891f503a1492673dcbea491',
#     'name': 'Kaplan International Toronto',
#     'location': {'address': '35 the esplanade',
#      'lat': 43.64587561049558,
#      'lng': -79.37538086699436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64587561049558,
#        'lng': -79.37538086699436}],
#      'distance': 207,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['35 the esplanade', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4afa3d28f964a520771722e3',
#     'name': 'Residences of the World Trade Centre',
#     'location': {'address': '10 Yonge St',
#      'crossStreet': 'at Queens Quay',
#      'lat': 43.64255070119169,
#      'lng': -79.37541604042053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64255070119169,
#        'lng': -79.37541604042053}],
#      'distance': 299,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Yonge St (at Queens Quay)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5a176309dab4b138e5c06c03',
#     'name': 'Kibo Sushi House',
#     'location': {'address': '16D Yonge St',
#      'crossStreet': 'Harbour St',
#      'lat': 43.643418,
#      'lng': -79.375694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643418,
#        'lng': -79.375694}],
#      'distance': 244,
#      'postalCode': 'M5E 2A1',
#      'cc': 'CA',
#      'neighborhood': 'Harbourfront',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['16D Yonge St (Harbour St)',
#       'Toronto ON M5E 2A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4ad9c89cf964a520cc1a21e3',
#     'name': "St Andrew's Market",
#     'location': {'address': 'Adelaide St West',
#      'crossStreet': 'Maud',
#      'lat': 43.64657998587439,
#      'lng': -79.37081255406537,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64657998587439,
#        'lng': -79.37081255406537}],
#      'distance': 284,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Adelaide St West (Maud)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b8368bff964a520990531e3',
#     'name': 'Green P',
#     'location': {'address': '2 Church St.',
#      'crossStreet': 'at The Esplanade',
#      'lat': 43.64700201774003,
#      'lng': -79.37357933690848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64700201774003,
#        'lng': -79.37357933690848}],
#      'distance': 249,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2 Church St. (at The Esplanade)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bdb78f83904a593d1a94a9e',
#     'name': 'Esplanade Food Market',
#     'location': {'address': '25 The Esplanade',
#      'crossStreet': 'at Scott St',
#      'lat': 43.646695,
#      'lng': -79.375292,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646695,
#        'lng': -79.375292}],
#      'distance': 267,
#      'postalCode': 'M5E 1W5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade (at Scott St)',
#       'Toronto ON M5E 1W5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4aea299ef964a520e2b921e3',
#     'name': '18 Yonge Street',
#     'location': {'address': '18 Yonge St',
#      'crossStreet': 'at Harbour St',
#      'lat': 43.64457958052741,
#      'lng': -79.37620273692315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64457958052741,
#        'lng': -79.37620273692315}],
#      'distance': 234,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Yonge St (at Harbour St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '51428b69e4b0823a335fe683',
#     'name': 'lobby foyer',
#     'location': {'address': '12/16 Yonge St',
#      'crossStreet': 'Harbour St',
#      'lat': 43.6444,
#      'lng': -79.3756,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.6444, 'lng': -79.3756}],
#      'distance': 189,
#      'postalCode': 'm5e 1z9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['12/16 Yonge St (Harbour St)',
#       'Toronto ON m5e 1z9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4e84a22302d59a0afa184cc0',
#     'name': 'Harbour Star Cleaners',
#     'location': {'lat': 43.643158985707174,
#      'lng': -79.37513473238522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643158985707174,
#        'lng': -79.37513473238522}],
#      'distance': 232,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'shortName': 'Laundry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4dd45003b0fb7a332e66d85c',
#     'name': 'Feta & Olives',
#     'location': {'address': 'Pinnacle Centre',
#      'crossStreet': '16 Yonge St',
#      'lat': 43.64345108461817,
#      'lng': -79.3755659309737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64345108461817,
#        'lng': -79.3755659309737}],
#      'distance': 233,
#      'postalCode': 'M5G 1C9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Pinnacle Centre (16 Yonge St)',
#       'Toronto ON M5G 1C9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4d3999a497e0a1cd3a94653e',
#     'name': 'Metroland Digital Media',
#     'location': {'address': '1 Yonge Street',
#      'crossStreet': "Queen's Quay",
#      'lat': 43.643751,
#      'lng': -79.375425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643751,
#        'lng': -79.375425}],
#      'distance': 204,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["1 Yonge Street (Queen's Quay)",
#       'Toronto ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5168a9e6e4b089297708e6f1',
#     'name': 'Nova Dry Cleaners',
#     'location': {'address': '25 The Esplanade',
#      'crossStreet': 'Scott street',
#      'lat': 43.64610053508474,
#      'lng': -79.3758000879857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64610053508474,
#        'lng': -79.3758000879857}],
#      'distance': 249,
#      'postalCode': 'm5e 1w5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade (Scott street)',
#       'Toronto ON m5e 1w5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'shortName': 'Laundry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bba0ad17421a593b84cc340',
#     'name': 'Nails Station',
#     'location': {'address': '18 Yonge St',
#      'crossStreet': 'at Lakeshore Blvd',
#      'lat': 43.64461586768018,
#      'lng': -79.37602089714028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64461586768018,
#        'lng': -79.37602089714028}],
#      'distance': 219,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Yonge St (at Lakeshore Blvd)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4ad4c05df964a52055f620e3',
#     'name': 'Bier Markt Esplanade',
#     'location': {'address': '58 The Esplanade',
#      'crossStreet': 'at Church St.',
#      'lat': 43.64723602476138,
#      'lng': -79.37389161769812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64723602476138,
#        'lng': -79.37389161769812}],
#      'distance': 278,
#      'postalCode': 'M5E 1A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['58 The Esplanade (at Church St.)',
#       'Toronto ON M5E 1A6',
#       'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a02',
#       'name': 'Belgian Restaurant',
#       'pluralName': 'Belgian Restaurants',
#       'shortName': 'Belgian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5069d979e4b03ce13c07569a',
#     'name': 'Tilted Kilt',
#     'location': {'address': '38 The Esplanade',
#      'crossStreet': 'at Scott Street',
#      'lat': 43.646839368396485,
#      'lng': -79.37445154469805,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646839368396485,
#        'lng': -79.37445154469805}],
#      'distance': 248,
#      'postalCode': 'M5E 1A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['38 The Esplanade (at Scott Street)',
#       'Toronto ON M5E 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bbd6f6f8a4fb713750e3d9d',
#     'name': 'Due North Communications',
#     'location': {'address': '35 The Esplanade',
#      'crossStreet': 'at Yonge St',
#      'lat': 43.64543107931874,
#      'lng': -79.37561312904347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64543107931874,
#        'lng': -79.37561312904347}],
#      'distance': 199,
#      'postalCode': 'M5E 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['35 The Esplanade (at Yonge St)',
#       'Toronto ON M5E 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '54defb5b498eee339d77d665',
#     'name': 'Bluma Appel Theatre',
#     'location': {'lat': 43.6469461,
#      'lng': -79.3759458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6469461,
#        'lng': -79.3759458}],
#      'distance': 322,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b2184a9f964a520193d24e3',
#     'name': 'Scotland Yard Pub',
#     'location': {'address': '56 The Esplanade',
#      'crossStreet': 'btwn Scott St. and Church St.',
#      'lat': 43.64705292210499,
#      'lng': -79.37405970553979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64705292210499,
#        'lng': -79.37405970553979}],
#      'distance': 261,
#      'postalCode': 'M5E 1A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade (btwn Scott St. and Church St.)',
#       'Toronto ON M5E 1A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '91450129'},
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4cbfbb3ca0c4f04dfef65631',
#     'name': 'Redpath Sugar',
#     'location': {'address': '95 Queens Quay',
#      'lat': 43.643356428801326,
#      'lng': -79.3704496138877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643356428801326,
#        'lng': -79.3704496138877}],
#      'distance': 278,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['95 Queens Quay', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4d2c6c5cc406721e9b9f94b6',
#     'name': 'Canada Square Dental Office',
#     'location': {'address': '2200 Yonge Street',
#      'crossStreet': 'Yonge Street & Eglinton Ave.',
#      'lat': 43.642528,
#      'lng': -79.373638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642528,
#        'lng': -79.373638}],
#      'distance': 251,
#      'postalCode': 'M4S',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2200 Yonge Street (Yonge Street & Eglinton Ave.)',
#       'Toronto ON M4S',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4d3b60cc0333a093be0d5e34',
#     'name': 'International News',
#     'location': {'address': '79 Front St E',
#      'lat': 43.646928930822796,
#      'lng': -79.37252825203011,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646928930822796,
#        'lng': -79.37252825203011}],
#      'distance': 248,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['79 Front St E', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4f04ad622fb6e1c99f3db0b9',
#       'name': 'Newsstand',
#       'pluralName': 'Newsstands',
#       'shortName': 'Newsstand',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5081541de4b0361f6592b1f4',
#     'name': 'Government of Canada',
#     'location': {'address': '1 Front Street West',
#      'crossStreet': 'Yonge Street',
#      'lat': 43.64587141278963,
#      'lng': -79.37677336814899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64587141278963,
#        'lng': -79.37677336814899}],
#      'distance': 304,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Front Street West (Yonge Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b74e02df964a5205ef62de3',
#     'name': 'Pinnacle Centre - 12 Yonge St',
#     'location': {'address': '12 Yonge St',
#      'crossStreet': 'at Harbour St',
#      'lat': 43.64317240203011,
#      'lng': -79.37632797002125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64317240203011,
#        'lng': -79.37632797002125}],
#      'distance': 301,
#      'cc': 'CA',
#      'neighborhood': 'Harbourfront',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['12 Yonge St (at Harbour St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '56941a80498ed67a1e722fe3',
#     'name': 'Acquia',
#     'location': {'address': '111 George St. Unit 201',
#      'lat': 43.652475,
#      'lng': -79.371025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652475,
#        'lng': -79.371025}],
#      'distance': 877,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 George St. Unit 201', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b1069daf964a520e76f23e3',
#     'name': 'Kokoro Sushi',
#     'location': {'address': '16D Yonge St',
#      'lat': 43.643495365711914,
#      'lng': -79.375640234844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643495365711914,
#        'lng': -79.375640234844}],
#      'distance': 235,
#      'postalCode': 'M5M 3G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['16D Yonge St', 'Toronto ON M5M 3G5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4dd2c9c1ae60da0ebecf3a09',
#     'name': 'Publicitas Toronto',
#     'location': {'address': 'Queen Street East',
#      'lat': 43.6453647613525,
#      'lng': -79.3702354431152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6453647613525,
#        'lng': -79.3702354431152}],
#      'distance': 256,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Queen Street East', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5258405c11d2a86ad8a71d60',
#     'name': '25 The Esplanade (gym)',
#     'location': {'lat': 43.646599010769435,
#      'lng': -79.3757780928356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646599010769435,
#        'lng': -79.3757780928356}],
#      'distance': 284,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4de572e8d4c09fc98b689cdf',
#     'name': 'Novotel - Champagne Suite',
#     'location': {'lat': 43.64681882206217,
#      'lng': -79.37455185495752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64681882206217,
#        'lng': -79.37455185495752}],
#      'distance': 249,
#      'cc': 'CA',
#      'neighborhood': 'St. Lawrence',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5b15659b1c062d0024e7cf81',
#     'name': 'Eggspectation',
#     'location': {'address': '22 The Esplanade',
#      'lat': 43.646526,
#      'lng': -79.375134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646526,
#        'lng': -79.375134}],
#      'distance': 244,
#      'postalCode': 'M5E 1A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['22 The Esplanade', 'Toronto ON M5E 1A6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '51689f0be4b0024a275d10c5',
#     'name': 'Dog Crap Alley',
#     'location': {'lat': 43.64532965614004,
#      'lng': -79.37643244631754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64532965614004,
#        'lng': -79.37643244631754}],
#      'distance': 259,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4cc9bd00bcb1b1f7a91c118a',
#     'name': 'London Condo Gym',
#     'location': {'address': '38 The Esplanade',
#      'lat': 43.64693164351224,
#      'lng': -79.37515122886283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64693164351224,
#        'lng': -79.37515122886283}],
#      'distance': 282,
#      'cc': 'CA',
#      'city': 'Toronto Division',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['38 The Esplanade',
#       'Toronto Division ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4de59953b0fb5cbf0e9e8054',
#     'name': 'World Trade BBQ',
#     'location': {'lat': 43.64256313472196,
#      'lng': -79.37501925695969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64256313472196,
#        'lng': -79.37501925695969}],
#      'distance': 281,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4f1f2cece4b01d27e71f2a33',
#     'name': 'SkyLounge',
#     'location': {'address': 'Yonge',
#      'crossStreet': 'Queens Quay',
#      'lat': 43.643879941512836,
#      'lng': -79.37547565899231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643879941512836,
#        'lng': -79.37547565899231}],
#      'distance': 200,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge (Queens Quay)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b56a44ff964a5206e1728e3',
#     'name': 'The Keg Steakhouse + Bar',
#     'location': {'address': '26 The Esplanade',
#      'lat': 43.64667637593993,
#      'lng': -79.37482154865866,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64667637593993,
#        'lng': -79.37482154865866}],
#      'distance': 244,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['26 The Esplanade', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c80f8df6cc2b7139e32159b',
#     'name': 'HMCS Fredericton',
#     'location': {'address': "Queen's Quay",
#      'crossStreet': 'at the foot of Yonge Street',
#      'lat': 43.64325423295281,
#      'lng': -79.37450786405944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64325423295281,
#        'lng': -79.37450786405944}],
#      'distance': 194,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["Queen's Quay (at the foot of Yonge Street)",
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12d951735',
#       'name': 'Boat or Ferry',
#       'pluralName': 'Boats or Ferries',
#       'shortName': 'Boat / Ferry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
# ...
#      'country': 'Canada',
#      'formattedAddress': ['16 Yonge Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a31',
#       'name': 'TV Station',
#       'pluralName': 'TV Stations',
#       'shortName': 'TV Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bae107df964a52027803be3',
#     'name': 'Egglicious',
#     'location': {'lat': 43.644489,
#      'lng': -79.374487,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644489,
#        'lng': -79.374487}],
#      'distance': 100,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4e4d4e52e4cdcf486c76b056',
#     'name': 'Innovative Research Group',
#     'location': {'address': '56 The Esplanade, Suite 310',
#      'lat': 43.6468268,
#      'lng': -79.3756486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6468268,
#        'lng': -79.3756486}],
#      'distance': 296,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'QC',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade, Suite 310',
#       'Toronto QC',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bc7848192b376b073de4f3a',
#     'name': 'Wills & Co Media',
#     'location': {'address': '56 The Esplanade suite 216',
#      'crossStreet': 'Church st',
#      'lat': 43.646968,
#      'lng': -79.37442,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646968,
#        'lng': -79.37442}],
#      'distance': 260,
#      'postalCode': 'M5E 1A7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade suite 216 (Church st)',
#       'Toronto ON M5E 1A7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '518b9cd77dd2be0927a104a5',
#     'name': 'Rebel Trail Web Solutions Inc',
#     'location': {'address': '1 Yonge Street, Suite 1801',
#      'lat': 43.64382398768501,
#      'lng': -79.37551259994507,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64382398768501,
#        'lng': -79.37551259994507}],
#      'distance': 206,
#      'postalCode': 'M5E 1W7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Yonge Street, Suite 1801',
#       'Toronto ON M5E 1W7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5105bbd4e4b0a221d6d03edd',
#     'name': 'Theatre C',
#     'location': {'address': '18 Harbour St',
#      'lat': 43.6432,
#      'lng': -79.3755,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.6432, 'lng': -79.3755}],
#      'distance': 248,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Harbour St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d17f941735',
#       'name': 'Movie Theater',
#       'pluralName': 'Movie Theaters',
#       'shortName': 'Movie Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '51549e02e4b05e27e1c27d3f',
#     'name': 'Diabsolut',
#     'location': {'address': '56 The Esplanade',
#      'lat': 43.64713035722445,
#      'lng': -79.37407895170864,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64713035722445,
#        'lng': -79.37407895170864}],
#      'distance': 269,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c38a36ca52cb713786d5f26',
#     'name': 'Knot PR',
#     'location': {'address': '56 The Esplanade, Suite 305',
#      'crossStreet': 'The Esplanade & Church St.',
#      'lat': 43.64722180176724,
#      'lng': -79.37474981374038,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64722180176724,
#        'lng': -79.37474981374038}],
#      'distance': 296,
#      'postalCode': 'M5E 1A7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade, Suite 305 (The Esplanade & Church St.)',
#       'Toronto ON M5E 1A7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '77373817'},
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c39d8d1edba95219b74d625',
#     'name': 'Cityzen Development Group',
#     'location': {'address': '56 The Esplanade',
#      'crossStreet': 'btw Church & Scott',
#      'lat': 43.646863,
#      'lng': -79.374427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646863,
#        'lng': -79.374427}],
#      'distance': 249,
#      'postalCode': 'M5E 1A7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Esplanade (btw Church & Scott)',
#       'Toronto ON M5E 1A7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '50f819d3c84c56ca2ddbc576',
#     'name': 'Brand Networks',
#     'location': {'address': '56 The Espanlade',
#      'lat': 43.646976032048855,
#      'lng': -79.37416076660156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646976032048855,
#        'lng': -79.37416076660156}],
#      'distance': 254,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 The Espanlade', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '512fe5dce4b054cc5b0f76c6',
#     'name': 'Canadian Screen Awards',
#     'location': {'address': '255 Front St W',
#      'lat': 43.64682452245506,
#      'lng': -79.37565162062124,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64682452245506,
#        'lng': -79.37565162062124}],
#      'distance': 296,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 Front St W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4c180fc14ff90f475be30d49',
#     'name': "The Dougler's",
#     'location': {'address': '25 The Esplanade',
#      'lat': 43.646489,
#      'lng': -79.374352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646489,
#        'lng': -79.374352}],
#      'distance': 208,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade', 'Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5432b5c3498e9bcafb71b125',
#     'name': 'Soap Stories',
#     'location': {'address': '100 King Street West (First Canadian Place)',
#      'lat': 43.64530085356717,
#      'lng': -79.37517322416176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64530085356717,
#        'lng': -79.37517322416176}],
#      'distance': 161,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King Street West (First Canadian Place)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '5105c4ede4b0a3ace1a69539',
#     'name': 'Fifth floor BBQ Patio, Pinnacle Centre',
#     'location': {'address': '12 Yonge St',
#      'lat': 43.64356274740431,
#      'lng': -79.3756021314469,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64356274740431,
#        'lng': -79.3756021314469}],
#      'distance': 228,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['12 Yonge St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4d1d8f2ae56f6ea8e8c75c1d',
#     'name': "Dubien's",
#     'location': {'address': '25 The Esplanade',
#      'lat': 43.64653,
#      'lng': -79.375275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64653,
#        'lng': -79.375275}],
#      'distance': 251,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['25 The Esplanade', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4cffebd36923721e1bf0c13b',
#     'name': 'TTI Canada HQ',
#     'location': {'lat': 43.64669886729789,
#      'lng': -79.37476631028653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64669886729789,
#        'lng': -79.37476631028653}],
#      'distance': 244,
#      'cc': 'CA',
#      'city': 'Markham',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Markham ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '528a7b9011d26ac4c8b17428',
#     'name': 'Green Living Enterprises',
#     'location': {'lat': 43.64712827284716,
#      'lng': -79.37367203302772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64712827284716,
#        'lng': -79.37367203302772}],
#      'distance': 264,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4da650befa8c94f8b84d0d03',
#     'name': 'Studio+ HQ',
#     'location': {'lat': 43.6468,
#      'lng': -79.374088,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6468,
#        'lng': -79.374088}],
#      'distance': 234,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4bdb06523904a593b656489e',
#     'name': 'London on the Esplanade',
#     'location': {'address': '1 Scott St.',
#      'crossStreet': 'Scott and Esplanade',
#      'lat': 43.646941586989506,
#      'lng': -79.37491418596888,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646941586989506,
#        'lng': -79.37491418596888}],
#      'distance': 274,
#      'postalCode': 'M5E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Scott St. (Scott and Esplanade)',
#       'Toronto ON M5E',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4b966378f964a52088c934e3',
#     'name': 'Pinnicle Business Centre',
#     'location': {'lat': 43.643422,
#      'lng': -79.375307,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643422,
#        'lng': -79.375307}],
#      'distance': 220,
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['Ontario', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1556577351',
#     'hasPerk': False},
#    {'id': '4ad4c062f964a520fbf720e3',
#     'name': 'St. Lawrence Market (South Building)',
#     'location': {'address': '93 Front St E',
#      'crossStreet': 'at Lower Jarvis St',
#      'lat': 43.64874320223593,
#      'lng': -79.37159697627527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64874320223593,
#        'lng': -79.37159697627527}],
#      'distance': 463,
#      'postalCode': 'M5E 1C3',
#      'cc': 'CA',
#      'neighborhood': 'St. Lawrence',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['93 Front St E (at Lower Jarvis St)',
#       'Toronto ON M5E 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa941735',
#       'name': 'Farmers Market',
#       'pluralName': 'Farmers Markets',
#       'shortName': "Farmer's Market",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1556577351',
#     'hasPerk': False}],
#   'confident': False}}

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
all_venues = results['response']['venues']

# %%
nearby_venues = json_normalize(all_venues)
nearby_venues.columns
# Out:
# Index(['categories', 'hasPerk', 'id', 'location.address', 'location.cc',
#        'location.city', 'location.country', 'location.crossStreet',
#        'location.distance', 'location.formattedAddress',
#        'location.labeledLatLngs', 'location.lat', 'location.lng',
#        'location.neighborhood', 'location.postalCode', 'location.state',
#        'name', 'referralId', 'venuePage.id'],
#       dtype='object')

# %%
chosen_columns = ['name', 'location.lat', 'location.lng', 'location.neighborhood','location.distance']
venues = nearby_venues.loc[:,chosen_columns]
venues.iloc[3,:]
venues.head(10)
# Out:
# /anaconda3/anaconda2/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                    name  location.lat  location.lng  \
# 0                                  Bell     43.641570    -79.379780
# 1                  Waterclub Gym & Pool     43.640023    -79.381777
# 2                          Harbourfront     43.639526    -79.380688
# 3                              Ten York     43.641125    -79.381022
# 4                            SP Parking     43.640091    -79.381494
# 5                 Infinity Condominiums     43.642506    -79.382970
# 6            Artscape Daniels Launchpad     43.644298    -79.368339
# 7  Down On The Corner Put Im The Street     43.640226    -79.380628
# 8                       City of Toronto     43.650072    -79.383888
# 9                      Scotiabank Arena     43.643446    -79.379040
#
#    location.neighborhood  location.distance
# 0                    NaN                179
# 1                    NaN                 88
# 2                    NaN                167
# 3                    NaN                 68
# 4                    NaN                 83
# 5                    NaN                212
# 6                    NaN               1147
# 7                    NaN                111
# 8                    NaN               1044
# 9                    NaN                365

# %% [markdown]
# ## Now generalize to all Downtown neighborhoods
#
# ### Note:
# What is a little confusing is that the foursquare lookup returns NaN for most neighborhood names.  However, this is probably irrelevant because we have used the lat/lon for a particular neighborhood, and returned all venues within a certain radius of that.  In a sense then we have figured out the neighborhood on our own and don't need to rely on FourSquare naming them for us.
#
# Next we're going to loop through all of downtown Toronto's neighborhoods and return their venues:

# %%
# copied from class-provided notebook
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    LIMIT = 250
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],
                                   latitudes=toronto['Latitude'],
                                   longitudes=toronto['Longitude']
                                  )

toronto_venues.shape
# Out:
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Christie
# (1291, 7)

# %%
toronto_venues.head()
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                    Rosedale              43.679563              -79.377529
# 1                    Rosedale              43.679563              -79.377529
# 2                    Rosedale              43.679563              -79.377529
# 3                    Rosedale              43.679563              -79.377529
# 4  Cabbagetown,St. James Town              43.667967              -79.367675
#
#                   Venue  Venue Latitude  Venue Longitude Venue Category
# 0         Rosedale Park       43.682328       -79.378934     Playground
# 1          Whitney Park       43.682036       -79.373788           Park
# 2  Alex Murray Parkette       43.678300       -79.382773           Park
# 3        Milkman's Lane       43.676352       -79.373842          Trail
# 4           Cranberries       43.667843       -79.369407          Diner

# %% [markdown]
# We now have over 1000 venues.  Let's group by neighborhood and see how many we have per neighborhood.

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Adelaide,King,Richmond                                                100
# Berczy Park                                                            55
# CN Tower,Bathurst Quay,Island airport,Harbourfr...                     14
# Cabbagetown,St. James Town                                             47
# Central Bay Street                                                     89
# Chinatown,Grange Park,Kensington Market                               100
# Christie                                                               16
# Church and Wellesley                                                   86
# Commerce Court,Victoria Hotel                                         100
# Design Exchange,Toronto Dominion Centre                               100
# First Canadian Place,Underground city                                 100
# Harbord,University of Toronto                                          36
# Harbourfront East,Toronto Islands,Union Station                       100
# Harbourfront,Regent Park                                               48
# Rosedale                                                                4
# Ryerson,Garden District                                               100
# St. James Town                                                        100
# Stn A PO Boxes 25 The Esplanade                                        96
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Adelaide,King,Richmond                                                 100
# Berczy Park                                                             55
# CN Tower,Bathurst Quay,Island airport,Harbourfr...                      14
# Cabbagetown,St. James Town                                              47
# Central Bay Street                                                      89
# Chinatown,Grange Park,Kensington Market                                100
# Christie                                                                16
# Church and Wellesley                                                    86
# Commerce Court,Victoria Hotel                                          100
# Design Exchange,Toronto Dominion Centre                                100
# First Canadian Place,Underground city                                  100
# Harbord,University of Toronto                                           36
# Harbourfront East,Toronto Islands,Union Station                        100
# Harbourfront,Regent Park                                                48
# Rosedale                                                                 4
# Ryerson,Garden District                                                100
# St. James Town                                                         100
# Stn A PO Boxes 25 The Esplanade                                         96
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Adelaide,King,Richmond                                100             100
# Berczy Park                                            55              55
# CN Tower,Bathurst Quay,Island airport,Harbourfr...     14              14
# Cabbagetown,St. James Town                             47              47
# Central Bay Street                                     89              89
# Chinatown,Grange Park,Kensington Market               100             100
# Christie                                               16              16
# Church and Wellesley                                   86              86
# Commerce Court,Victoria Hotel                         100             100
# Design Exchange,Toronto Dominion Centre               100             100
# First Canadian Place,Underground city                 100             100
# Harbord,University of Toronto                          36              36
# Harbourfront East,Toronto Islands,Union Station       100             100
# Harbourfront,Regent Park                               48              48
# Rosedale                                                4               4
# Ryerson,Garden District                               100             100
# St. James Town                                        100             100
# Stn A PO Boxes 25 The Esplanade                        96              96
#
#                                                     Venue Longitude  \
# Neighborhood
# Adelaide,King,Richmond                                          100
# Berczy Park                                                      55
# CN Tower,Bathurst Quay,Island airport,Harbourfr...               14
# Cabbagetown,St. James Town                                       47
# Central Bay Street                                               89
# Chinatown,Grange Park,Kensington Market                         100
# Christie                                                         16
# Church and Wellesley                                             86
# Commerce Court,Victoria Hotel                                   100
# Design Exchange,Toronto Dominion Centre                         100
# First Canadian Place,Underground city                           100
# Harbord,University of Toronto                                    36
# Harbourfront East,Toronto Islands,Union Station                 100
# Harbourfront,Regent Park                                         48
# Rosedale                                                          4
# Ryerson,Garden District                                         100
# St. James Town                                                  100
# Stn A PO Boxes 25 The Esplanade                                  96
#
#                                                     Venue Category
# Neighborhood
# Adelaide,King,Richmond                                         100
# Berczy Park                                                     55
# CN Tower,Bathurst Quay,Island airport,Harbourfr...              14
# Cabbagetown,St. James Town                                      47
# Central Bay Street                                              89
# Chinatown,Grange Park,Kensington Market                        100
# Christie                                                        16
# Church and Wellesley                                            86
# Commerce Court,Victoria Hotel                                  100
# Design Exchange,Toronto Dominion Centre                        100
# First Canadian Place,Underground city                          100
# Harbord,University of Toronto                                   36
# Harbourfront East,Toronto Islands,Union Station                100
# Harbourfront,Regent Park                                        48
# Rosedale                                                         4
# Ryerson,Garden District                                        100
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                 96

# %% [markdown]
# It seems like we don't get more than 100 venues per neighborhood. Even though I've raised the limit to 250 or higher.  this is probably a limit on the per-lookup results from FourSquare.

# %%
print("The number of unique venues are")
len(toronto_venues['Venue Category'].unique())
# Out:
# The number of unique venues are
# 204

# %% [markdown]
# # Conclusion
#
# I've used this section to gain experience with Foursquare and Toronto Neighborhoods.  Given that it's only worth 3 points, I don't think the assignment is intended to completely replicate the k-means clustering example given from NYC.  I'm going to move on and use my time more on the Capstone project itself.
